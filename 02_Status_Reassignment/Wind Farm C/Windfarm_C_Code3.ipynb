# %% [markdown]
# ## Wind Farm C Code 3 (Strict for Front Row Turbines)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
import os

# List of dataset IDs
dataset_ids = [8,11,12,28,32,33,36,39,43,44,54,55,61,63,75,90,91,93] ##As per determined windfarm layout, these datasets belong to front row


# Paths
input_dir = r"D:\Master Thesis New Data Set\CARE DATA SET\CARE_To_Compare\Wind Farm C\Wind Farm C\datasets"
output_dir = r"D:\Master Thesis New Data Set\Final DataSet\Wind Farm C Code 3"
os.makedirs(output_dir, exist_ok=True)

# Function to calculate ideal power
def get_ideal_power(wind_speed, cut_in, rated_speed, rated_power):
    if wind_speed < cut_in:
        return 0
    elif wind_speed < rated_speed:
        return rated_power * ((wind_speed - cut_in) / (rated_speed - cut_in))**3
    else:
        return rated_power

# Loop through each dataset
for dataset_id in dataset_ids:
    try:
        print(f"\n📂 Processing dataset {dataset_id}...")

        # Load data
        file_path = os.path.join(input_dir, f"{dataset_id}.csv")
        df = pd.read_csv(file_path, delimiter=';')
        df_2 = df.copy()

        # Select relevant columns
        cols = ['power_2_avg','power_6_avg', 'sensor_76_avg', 'sensor_124_avg', 'status_type_id', 'train_test', 'wind_speed_236_avg']
        df = df[cols]
        df['power_6_avg'] = df['power_6_avg'].apply(lambda x: max(x, 0))

        # Filter
        df_filtered = df[
            (df['sensor_76_avg'] <= 2) & 
            (df['sensor_76_avg'] >= -5) & 
            (df['sensor_124_avg'] >= -2) & 
            (df['sensor_124_avg'] <= 2) & 
            (df['status_type_id'] == 0) &
            (df['train_test'] == 'train')
        ].dropna(subset=['wind_speed_236_avg', 'power_6_avg'])

        df_sorted = df_filtered.sort_values(by='wind_speed_236_avg')
        original_max_power = df_sorted['power_6_avg'].max()
        df_sorted['power_6_avg'] = df_sorted['power_6_avg'] / original_max_power

        rated_band = df_sorted[
            (df_sorted['power_6_avg'] >= 0.98) & 
            (df_sorted['power_6_avg'] <= 1.02) & 
            (df_sorted['wind_speed_236_avg'] >= 10) & 
            (df_sorted['wind_speed_236_avg'] <= 12)
        ]
        rated_speed = rated_band['wind_speed_236_avg'].min()
        rated_power = 1

        wind_speed_3_df = df_sorted[(df_sorted['wind_speed_236_avg'] >= 2.98) & (df_sorted['wind_speed_236_avg'] <= 3.02)]
        min_power_at_3 = wind_speed_3_df['power_6_avg'].min()

        # Solve for cut-in speed
        def equation(cut_in): return rated_power * ((3 - cut_in) / (rated_speed - cut_in))**3 - min_power_at_3
        cut_in = fsolve(equation, 1.0)[0]

        # Normalize full dataset
        df['power_6_avg_norm'] = df['power_6_avg'] / original_max_power

        # Status reassignment
        def reassign_status(row):
            wind_speed = row['wind_speed_236_avg']
            pitch_deg = row['sensor_76_avg']
            yaw_deg = row['sensor_124_avg']
            actual_power = row['power_6_avg_norm']
            current_status = row['status_type_id']

                
            if wind_speed < 3:
                return current_status

            pitch_rad = np.deg2rad(pitch_deg)
            yaw_rad = np.deg2rad(yaw_deg)
            tol_mult = (np.cos(pitch_rad)**3) 
            tol_mult = np.clip(tol_mult, 0, 1)

            ideal_power = get_ideal_power(wind_speed, cut_in, rated_speed, rated_power)
            threshold = ideal_power * tol_mult 

            if current_status in [3, 4]:
                if actual_power <= 0.10:
                    return current_status
                return 0 if actual_power >= threshold else 5

            return 0 if actual_power >= threshold else 5

        df['status_type_id_original'] = df['status_type_id']
        print("🔍 Original status_type_id distribution:")
        print(df['status_type_id'].value_counts())

        df['status_type_id'] = df.apply(reassign_status, axis=1)

        print("🔁 New status_type_id distribution:")
        print(df['status_type_id'].value_counts())

        # Save result
        df_2['status_type_id'] = df['status_type_id']
        output_path = os.path.join(output_dir, f"{dataset_id}_WindFarm_C.csv")
        df_2.to_csv(output_path, index=False)
        print(f"✅ Dataset {dataset_id} processed and saved.")
    
    except Exception as e:
        print(f"❌ Failed to process dataset {dataset_id}: {e}")
# Out:
# 📂 Processing dataset 1...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    47264
# 3     3375
# 5     2168
# 4      762
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    34279
# 5    15422
# 3     3343
# 4      525
# Name: count, dtype: int64
# ✅ Dataset 1 processed and saved.
#
# 📂 Processing dataset 4...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49760
# 3     6076
# 5      400
# 4      213
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    35768
# 5    14505
# 3     6057
# 4      119
# Name: count, dtype: int64
# ✅ Dataset 4 processed and saved.
#
# 📂 Processing dataset 5...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    47640
# 3     4252
# 5      520
# 4      383
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    33568
# 5    14724
# 3     4150
# 4      353
# Name: count, dtype: int64
# ✅ Dataset 5 processed and saved.
#
# 📂 Processing dataset 6...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    46335
# 3     6445
# 5     1646
# 4      439
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    32970
# 5    15066
# 3     6417
# 4      412
# Name: count, dtype: int64
# ✅ Dataset 6 processed and saved.
#
# 📂 Processing dataset 8...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    51472
# 3     2806
# 5      456
# 4       68
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    32962
# 5    18981
# 3     2796
# 4       63
# Name: count, dtype: int64
# ✅ Dataset 8 processed and saved.
#
# 📂 Processing dataset 9...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    51238
# 3     4083
# 5      497
# 4      211
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36279
# 5    15536
# 3     4071
# 4      143
# Name: count, dtype: int64
# ✅ Dataset 9 processed and saved.
#
# 📂 Processing dataset 11...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    46022
# 3     5504
# 5     3957
# 4      954
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    33147
# 5    17057
# 3     5375
# 4      858
# Name: count, dtype: int64
# ✅ Dataset 11 processed and saved.
#
# 📂 Processing dataset 12...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    52818
# 3     2545
# 5      476
# 4      268
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    37139
# 5    16301
# 3     2513
# 4      154
# Name: count, dtype: int64
# ✅ Dataset 12 processed and saved.
#
# 📂 Processing dataset 15...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    48307
# 3     4328
# 5     1642
# 4      156
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    34521
# 5    15465
# 3     4311
# 4      136
# Name: count, dtype: int64
# ✅ Dataset 15 processed and saved.
#
# 📂 Processing dataset 16...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    45220
# 3     5440
# 5     2189
# 4      719
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    32891
# 5    14735
# 3     5425
# 4      517
# Name: count, dtype: int64
# ✅ Dataset 16 processed and saved.
#
# 📂 Processing dataset 18...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    48111
# 3     4036
# 5      472
# 4      229
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    34825
# 5    13809
# 3     4021
# 4      193
# Name: count, dtype: int64
# ✅ Dataset 18 processed and saved.
#
# 📂 Processing dataset 20...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49761
# 3     2036
# 4     1148
# 5     1056
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36539
# 5    14595
# 3     1999
# 4      868
# Name: count, dtype: int64
# ✅ Dataset 20 processed and saved.
#
# 📂 Processing dataset 28...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    47804
# 3     7159
# 4      484
# 5      471
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    34742
# 5    13925
# 3     7047
# 4      204
# Name: count, dtype: int64
# ✅ Dataset 28 processed and saved.
#
# 📂 Processing dataset 29...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    43098
# 3    10692
# 5      553
# 4      522
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    30514
# 5    13179
# 3    10684
# 4      488
# Name: count, dtype: int64
# ✅ Dataset 29 processed and saved.
#
# 📂 Processing dataset 30...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    50278
# 3     4899
# 5      641
# 4      293
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    35459
# 5    15517
# 3     4891
# 4      244
# Name: count, dtype: int64
# ✅ Dataset 30 processed and saved.
#
# 📂 Processing dataset 31...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49591
# 3     3987
# 5      719
# 4      292
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    32508
# 5    17883
# 3     3963
# 4      235
# Name: count, dtype: int64
# ✅ Dataset 31 processed and saved.
#
# 📂 Processing dataset 32...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49461
# 3     4732
# 5      544
# 4      272
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36170
# 5    13920
# 3     4706
# 4      213
# Name: count, dtype: int64
# ✅ Dataset 32 processed and saved.
#
# 📂 Processing dataset 33...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49613
# 3     4727
# 4      914
# 5      619
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    34683
# 5    15647
# 3     4698
# 4      845
# Name: count, dtype: int64
# ✅ Dataset 33 processed and saved.
#
# 📂 Processing dataset 35...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    47176
# 3     3389
# 5     1262
# 4      788
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    33922
# 5    14803
# 3     3357
# 4      533
# Name: count, dtype: int64
# ✅ Dataset 35 processed and saved.
#
# 📂 Processing dataset 36...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49741
# 5     3717
# 3     1772
# 4      218
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36346
# 5    17251
# 3     1746
# 4      105
# Name: count, dtype: int64
# ✅ Dataset 36 processed and saved.
#
# 📂 Processing dataset 37...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    45997
# 3     6305
# 5      851
# 4      560
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    31593
# 5    15288
# 3     6294
# 4      538
# Name: count, dtype: int64
# ✅ Dataset 37 processed and saved.
#
# 📂 Processing dataset 39...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    44090
# 3     5941
# 5     3416
# 4      280
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    32751
# 5    14900
# 3     5891
# 4      185
# Name: count, dtype: int64
# ✅ Dataset 39 processed and saved.
#
# 📂 Processing dataset 41...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    50718
# 5     2638
# 3     2193
# 4      117
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    33039
# 5    20346
# 3     2181
# 4      100
# Name: count, dtype: int64
# ✅ Dataset 41 processed and saved.
#
# 📂 Processing dataset 43...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    45160
# 3     6348
# 5     3377
# 4      268
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    33591
# 5    15138
# 3     6292
# 4      132
# Name: count, dtype: int64
# ✅ Dataset 43 processed and saved.
#
# 📂 Processing dataset 44...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    58410
# 3     3719
# 5      687
# 4      187
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    41749
# 5    17401
# 3     3678
# 4      175
# Name: count, dtype: int64
# ✅ Dataset 44 processed and saved.
#
# 📂 Processing dataset 46...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    52449
# 3     2052
# 5      397
# 4      235
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    37004
# 5    15882
# 3     2043
# 4      204
# Name: count, dtype: int64
# ✅ Dataset 46 processed and saved.
#
# 📂 Processing dataset 47...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49400
# 3     3828
# 5      590
# 4      175
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    28038
# 5    22005
# 3     3814
# 4      136
# Name: count, dtype: int64
# ✅ Dataset 47 processed and saved.
#
# 📂 Processing dataset 48...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    41804
# 5     9825
# 3     3437
# 4      231
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    34233
# 5    17476
# 3     3411
# 4      177
# Name: count, dtype: int64
# ✅ Dataset 48 processed and saved.
#
# 📂 Processing dataset 49...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    47624
# 3     2673
# 5     2588
# 4      129
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    32071
# 5    18169
# 3     2662
# 4      112
# Name: count, dtype: int64
# ✅ Dataset 49 processed and saved.
#
# 📂 Processing dataset 50...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    50893
# 3     3209
# 5      738
# 4      313
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36314
# 5    15418
# 3     3197
# 4      224
# Name: count, dtype: int64
# ✅ Dataset 50 processed and saved.
#
# 📂 Processing dataset 54...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    47718
# 3     6818
# 4      528
# 5      521
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    33649
# 5    14950
# 3     6728
# 4      258
# Name: count, dtype: int64
# ✅ Dataset 54 processed and saved.
#
# 📂 Processing dataset 55...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    51942
# 3     3204
# 5      501
# 4      106
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    32455
# 5    20006
# 3     3193
# 4       99
# Name: count, dtype: int64
# ✅ Dataset 55 processed and saved.
#
# 📂 Processing dataset 56...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49460
# 3     3275
# 5      469
# 4      212
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    35448
# 5    14528
# 3     3261
# 4      179
# Name: count, dtype: int64
# ✅ Dataset 56 processed and saved.
#
# 📂 Processing dataset 57...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    52144
# 3     2142
# 5      578
# 4      145
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    37223
# 5    15511
# 3     2136
# 4      139
# Name: count, dtype: int64
# ✅ Dataset 57 processed and saved.
#
# 📂 Processing dataset 58...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    50301
# 3     3475
# 5      443
# 4      214
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    35124
# 5    15688
# 3     3450
# 4      171
# Name: count, dtype: int64
# ✅ Dataset 58 processed and saved.
#
# 📂 Processing dataset 59...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49377
# 3     4130
# 5     1064
# 4      294
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36059
# 5    14512
# 3     4029
# 4      265
# Name: count, dtype: int64
# ✅ Dataset 59 processed and saved.
#
# 📂 Processing dataset 60...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    43654
# 3     9062
# 5      892
# 4      825
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    29370
# 5    15510
# 3     9029
# 4      524
# Name: count, dtype: int64
# ✅ Dataset 60 processed and saved.
#
# 📂 Processing dataset 61...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    50146
# 3     4527
# 5      740
# 4      172
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    35467
# 5    15532
# 3     4478
# 4      108
# Name: count, dtype: int64
# ✅ Dataset 61 processed and saved.
#
# 📂 Processing dataset 62...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    48961
# 3     3749
# 5      569
# 4      169
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    28010
# 5    21591
# 3     3714
# 4      133
# Name: count, dtype: int64
# ✅ Dataset 62 processed and saved.
#
# 📂 Processing dataset 63...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    50097
# 3     3780
# 5      606
# 4      382
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    38217
# 5    12630
# 3     3751
# 4      267
# Name: count, dtype: int64
# ✅ Dataset 63 processed and saved.
#
# 📂 Processing dataset 64...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    51981
# 3     1251
# 5     1103
# 4       98
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36819
# 5    16319
# 3     1228
# 4       67
# Name: count, dtype: int64
# ✅ Dataset 64 processed and saved.
#
# 📂 Processing dataset 65...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    52286
# 3     2648
# 5      680
# 4      304
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36048
# 5    16970
# 3     2642
# 4      258
# Name: count, dtype: int64
# ✅ Dataset 65 processed and saved.
#
# 📂 Processing dataset 66...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    47570
# 3     5092
# 5      697
# 4      144
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    28555
# 5    19750
# 3     5075
# 4      123
# Name: count, dtype: int64
# ✅ Dataset 66 processed and saved.
#
# 📂 Processing dataset 67...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    55971
# 3     3424
# 5     1793
# 4      301
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36334
# 5    21523
# 3     3396
# 4      236
# Name: count, dtype: int64
# ✅ Dataset 67 processed and saved.
#
# 📂 Processing dataset 70...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    51017
# 3     4397
# 5      493
# 4      131
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36168
# 5    15411
# 3     4375
# 4       84
# Name: count, dtype: int64
# ✅ Dataset 70 processed and saved.
#
# 📂 Processing dataset 75...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    53697
# 3     1890
# 5      422
# 4      152
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    38611
# 5    15548
# 3     1862
# 4      140
# Name: count, dtype: int64
# ✅ Dataset 75 processed and saved.
#
# 📂 Processing dataset 76...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    43469
# 5     4185
# 3     3731
# 4      701
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    31920
# 5    15937
# 3     3717
# 4      512
# Name: count, dtype: int64
# ✅ Dataset 76 processed and saved.
#
# 📂 Processing dataset 78...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    46536
# 3     5773
# 5      713
# 4      124
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    32354
# 5    14923
# 3     5763
# 4      106
# Name: count, dtype: int64
# ✅ Dataset 78 processed and saved.
#
# 📂 Processing dataset 79...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    50160
# 3     2524
# 5      392
# 4      205
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    34815
# 5    15779
# 3     2514
# 4      173
# Name: count, dtype: int64
# ✅ Dataset 79 processed and saved.
#
# 📂 Processing dataset 80...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    50244
# 3     4075
# 5      476
# 4      118
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36399
# 5    14379
# 3     4055
# 4       80
# Name: count, dtype: int64
# ✅ Dataset 80 processed and saved.
#
# 📂 Processing dataset 81...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    45698
# 3     6523
# 5     1258
# 4      453
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    31757
# 5    15254
# 3     6495
# 4      426
# Name: count, dtype: int64
# ✅ Dataset 81 processed and saved.
#
# 📂 Processing dataset 85...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    46552
# 3     3787
# 5     1728
# 4      350
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    30450
# 5    17983
# 3     3755
# 4      229
# Name: count, dtype: int64
# ✅ Dataset 85 processed and saved.
#
# 📂 Processing dataset 88...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    47670
# 3     3894
# 5     3706
# 4      171
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    35543
# 5    15911
# 3     3866
# 4      121
# Name: count, dtype: int64
# ✅ Dataset 88 processed and saved.
#
# 📂 Processing dataset 89...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    50819
# 3     2787
# 5      837
# 4      134
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    37074
# 5    14642
# 3     2762
# 4       99
# Name: count, dtype: int64
# ✅ Dataset 89 processed and saved.
#
# 📂 Processing dataset 90...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49981
# 3     4015
# 5      572
# 4      312
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    37854
# 5    12856
# 3     3974
# 4      196
# Name: count, dtype: int64
# ✅ Dataset 90 processed and saved.
#
# 📂 Processing dataset 91...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    50603
# 3     5181
# 5      549
# 4      275
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    36975
# 5    14331
# 3     5089
# 4      213
# Name: count, dtype: int64
# ✅ Dataset 91 processed and saved.
#
# 📂 Processing dataset 93...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    49880
# 3     4478
# 4      867
# 5      648
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    34924
# 5    15683
# 3     4447
# 4      819
# Name: count, dtype: int64
# ✅ Dataset 93 processed and saved.
#
# 📂 Processing dataset 94...
# 🔍 Original status_type_id distribution:
# status_type_id
# 0    48359
# 3     5144
# 5     1041
# 4      321
# Name: count, dtype: int64
# 🔁 New status_type_id distribution:
# status_type_id
# 0    34819
# 5    14657
# 3     5115
# 4      274
# Name: count, dtype: int64
# ✅ Dataset 94 processed and saved.
